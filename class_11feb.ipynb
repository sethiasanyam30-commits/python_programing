# %% [markdown]
# # there  are two arbitary lenght list of diff class in how many ways two student can siit  together

# %%
class_A = {"A1", "A2", "A3"}
class_B = {"B1", "B2", "B3"}

pairs = {(a, b) for a in class_A for b in class_B}

print(pairs)
print("Total ways:", len(pairs))
# Out:
# {('A2', 'B3'), ('A3', 'B3'), ('A2', 'B1'), ('A2', 'B2'), ('A3', 'B2'), ('A3', 'B1'), ('A1', 'B2'), ('A1', 'B3'), ('A1', 'B1')}
# Total ways: 9
