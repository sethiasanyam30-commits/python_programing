# %% [markdown]
# # Introduction to Python

# %% [markdown]
# Python is a high-level interpreted and object-oriented programming language with dynamic typing and binding For these two reasons it is especially useful for quick application development including scripting to coordinate various software components python offers powerful libraries and simple syntax which is easy to understand and learn Python programmers choose to focus on clarity because it helps to ensure code quality and because they know they will not be working on their code for long the language also facilitates module and package support which helps in structuring code Python incorporates a standard library with a freely distributable interpreter in source code form as well as in binary form for several popular operating systems The software can be freely used without incurring any costs.

# %% [markdown]
# **What is interactive programming in python?**

# %% [markdown]
# If a programming language offers the capability for a program to be run directly in the terminal getting immediate results that essentially translates to the fact that the code does not need a final compilation process The code can be directly executed line by line and hence the immediate output is produced This makes the testing process easier as the program can be directly run once the code is written.

# %% [markdown]
# **What is script programming in python?**

# %% [markdown]
# The process that happens when we try to execute the script using the compiler or interpreter with the help of the helper command is that the script is run If we consider the scenario of the Python script the script will run when the file is given to the Python interpreter using the following command in the terminal: python <file_name> The script will then be run generating the result.

# %% [markdown]
# *Interactive Python in Jupyter*

# %%
a = 15
b = 23
print("What is the product of a and b")
print(a*b)
# Out:
# What is the product of a and b
# 345

# %% [markdown]
# *Script mode in Jupyter Notebook*

# %%
# !python test1.py
# Out:
# sanyam king

# %% [markdown]
# **Dynamic Types in Python**

# %% [markdown]
# Python is a dynamically typed language and it implies that in Python variables need not be declared with the type of the data they will contain in advance Rather the type of the variable is decided at the time of execution of the program based on the value assigned to the variable.

# %% [markdown]
# a = 30

# %%
a=30

# %%
a
# Out:
# 30

# %%
a= 20
print(type(a))
a = 20/100
print(type(a))
a = "Text"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# **What is the command to check the datat type?**

# %% [markdown]
# The `type()` function in Python returns the type of the variable or value that is being used or held in that variable or value at that time or moment.

# %% [markdown]
# **What are immutable data types()?**

# %% [markdown]
# The data types where the value stored in them cannot be altered once they have been assigned are called immutable data types.
#
# Immutable Data Types comprise:
#
# 1 → Integer (int)
# 2 → Floating point (float)
# 3 -> Boolean (bool)
# 4 → String (str)
# 5 -> Frozenset
# 6 -> Tuple

# %%
a="sanyam"
print(a)
a="king"
print(a)
# Out:
# sanyam
# king

# %% [markdown]
# **What is a tuple?**

# %%
a =(1,5,2,3)
print(a)
print(type(a))
# a[1] =4
# Out:
# (1, 5, 2, 3)
# <class 'tuple'>

# %% [markdown]
# **Varriable - Native Python?**

# %% [markdown]
# A variable is a named memory location used for storing values and can be updated modified later on while running a programming language for a certain period of time.

# %% [markdown]
# `Naming and Using Variables:`

# %% [markdown]
# Variable names in Python may consist of letters digits and underscores They should start with a letter or underscore but not a digit For example **message_1** is valid whereas **1_message** is not.
#
# Variable names cannot contain spaces but underscores may be used to separate words For example **greeting_message** is fine but **greeting message** will result in an error.
#
# It is better to avoid using Python keywords or names of built-in functions such as **print** for naming variables since these words have special meanings in the language.
#
# Variable names must be short and indicative For instance **name** is better than **n** **student_name** is preferable to **s_n** and **name_length** is more comprehensible than **length_of_persons_name**.
#
# Also, be careful with letters such as lowercase **l** and uppercase **O** because they can be confused with the numbers **1** and **0** respectively.

# %% [markdown]
# ***Note: Python variable names should be written in lowercase Using the capital letters will not result in an error however using lowercase will be better to maintain coherence and readability.***

# %% [markdown]
# **Varriable Types?**

# %% [markdown]
# **String :** A string is a series of characters in a sequence, theye are written within "" or ''.

# %%
message = "Hello Python class assignments"
print(message)
# Out:
# Hello Python class assignments

# %% [markdown]
# **Python String Built-in Methods (Full List)**

# %% [markdown]
# **1) Case Conversion Methods**

# %% [markdown]
# `lower()`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# Return a copy of the string with all the cased characters converted to lowercase. For example:

# %%
a="SANYAM"
a.lower()
# Out:
# 'sanyam'

# %% [markdown]
# `upper()`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# This method creates and returns a **new string** in which all characters that have case are converted to **uppercase**. Keep in mind that calling `s.upper().isupper()` may still return `False` if the original string contains characters that do not have case, or if the Unicode category of the converted characters is not classified as **uppercase letters (“Lu”)**, but instead falls under another category such as **titlecase letters (“Lt”)**.

# %%
"sanyam".upper()
# Out:
# 'SANYAM'

# %% [markdown]
# `title()`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# This method returns a **title-cased form of the string**, in which each word begins with an **uppercase letter**, while all the other characters in the word are converted to **lowercase**.

# %%
"python programming project".title()
# Out:
# 'Python Programming Project'

# %% [markdown]
# `capitalize()`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# The `capitalize()` method returns a new string where only the first character is converted to a capital (titlecase) form and all remaining characters are changed to lowercase.
#
# **Updated in Python 3.8:**
# The first character is now converted to titlecase instead of uppercase As a result, characters such as digraphs will have only their initial letter capitalized rather than transforming the entire character.

# %%
"python project".capitalize()
# Out:
# 'Python project'

# %% [markdown]
# `swapcase()`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# The `swapcase()` method returns a new string in which all uppercase letters are converted to lowercase and all lowercase letters are converted to uppercase.

# %%
"pYthOn".swapcase()
# Out:
# 'PyTHoN'

# %% [markdown]
# `casefold()` (stronger lower)

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# This method returns a case-folded version of the string which is mainly used for case-insensitive comparisons.
#
# Casefolding works like converting a string to lowercase, but it is more thorough It removes all case differences to ensure accurate matching across different languages. For instance, the German letter **`ß`** is considered equivalent to **`ss`**. While `lower()` leaves `ß` unchanged because it is already lowercase, `casefold()` converts it to **`"ss"`**, making comparisons more reliable.

# %%
"GERMAN ß".casefold()
# Out:
# 'german ss'

# %% [markdown]
# **2) Remove Spaces / Cleanup**

# %% [markdown]
# `strip(chars=None)`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# This method returns a  new string with any leading and trailing characters removed The optional `chars` parameter defines which characters should be stripped from both ends of the string If `chars` is not provided or is set to `None` whitespace characters are removed by default.
#
# The `chars` parameter does not represent a specific prefix or suffix; instead any combination of the characters listed in `chars` will be removed from the beginning and end of the string.

# %%
"    king    ".strip()   # 'king'
# Out:
# 'king'

# %% [markdown]
# `lstrip(chars=None)`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# This method returns a new string with only the leading (left-side) characters removed The optional `chars` parameter specifies which characters should be removed If `chars` is not given or is set to `None` the method removes whitespace characters by default.
#
# The `chars` parameter does not act as a prefix instead any combination of the characters listed in `chars` will be stripped from the beginning of the string.

# %%
"    king".lstrip()    # 'king'
# Out:
# 'king'

# %% [markdown]
# `rstrip(chars=None)`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# This method returns a new string with only the trailing (right-side) characters removed The optional `chars` parameter defines which characters should be stripped If `chars` is not provided or is `None` whitespace characters are removed by default.
#
# The `chars` parameter does not function as a suffix instead any combination of the characters listed in `chars` will be removed from the end of the string.

# %%
"king     ".rstrip()   # 'king'
# Out:
# 'king'

# %% [markdown]
# **Search & Find**

# %% [markdown]
# `find(sub[, start[, end]])`

# %% [markdown]
# **Definition and Usage**

# %% [markdown]
# The `find()` method looks for a specific substring within a string and gives back the index where that substring first appears.
#
# It checks the string from the beginning to the end. If it finds the substring, it returns the index of its first character. If the substring isn’t in the string, it returns -1 instead of giving an error, which makes `find()` safer to use when you’re unsure if the substring exists.
#
# You can also use the optional start and end arguments to search only within a certain part of the string.
